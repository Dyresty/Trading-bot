# %%
pip install lumibot
# Out:
# Collecting lumibot
#   Downloading lumibot-3.9.17-py3-none-any.whl.metadata (10 kB)
# Collecting polygon-api-client>=1.13.3 (from lumibot)
#   Downloading polygon_api_client-1.14.4-py3-none-any.whl.metadata (952 bytes)
# Collecting alpaca-py>=0.28.1 (from lumibot)
#   Downloading alpaca_py-0.39.0-py3-none-any.whl.metadata (13 kB)
# Collecting alpha-vantage (from lumibot)
#   Downloading alpha_vantage-3.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting ibapi==9.81.1.post1 (from lumibot)
#   Downloading ibapi-9.81.1.post1.tar.gz (61 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting yfinance>=0.2.54 (from lumibot)
#   Downloading yfinance-0.2.54-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from lumibot) (3.10.1)
# Collecting quandl (from lumibot)
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy<2,>=1.20.0 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from lumibot) (1.23.5)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from lumibot) (2.2.3)
# Collecting pandas-market-calendars>=4.3.1 (from lumibot)
#   Downloading pandas_market_calendars-4.6.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting plotly>=5.18.0 (from lumibot)
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting sqlalchemy (from lumibot)
#   Downloading SQLAlchemy-2.0.38-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting bcrypt (from lumibot)
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting pytest (from lumibot)
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting scipy>=1.13.0 (from lumibot)
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting quantstats-lumi>=0.3.3 (from lumibot)
#   Downloading quantstats_lumi-0.3.3-py2.py3-none-any.whl.metadata (10 kB)
# Collecting python-dotenv (from lumibot)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting ccxt>=4.3.74 (from lumibot)
#   Downloading ccxt-4.4.65-py2.py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: termcolor in c:\users\rocha\appdata\roaming\python\python310\site-packages (from lumibot) (2.2.0)
# Collecting jsonpickle (from lumibot)
#   Downloading jsonpickle-4.0.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting apscheduler>=3.10.4 (from lumibot)
#   Downloading APScheduler-3.11.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting appdirs (from lumibot)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting pyarrow (from lumibot)
#   Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from lumibot) (4.67.1)
# Collecting lumiwealth-tradier>=0.1.16 (from lumibot)
#   Downloading lumiwealth_tradier-0.1.16-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pytz in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from lumibot) (2025.1)
# Collecting psycopg2-binary (from lumibot)
#   Downloading psycopg2_binary-2.9.10-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting exchange-calendars>=4.5.2 (from lumibot)
#   Downloading exchange_calendars-4.9-py3-none-any.whl.metadata (37 kB)
# Collecting duckdb (from lumibot)
#   Downloading duckdb-1.2.1-cp310-cp310-win_amd64.whl.metadata (995 bytes)
# Collecting tabulate (from lumibot)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting thetadata (from lumibot)
#   Downloading thetadata-0.9.11-py3-none-any.whl.metadata (3.3 kB)
# Collecting holidays (from lumibot)
#   Downloading holidays-0.68-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: psutil in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from lumibot) (7.0.0)
# Collecting openai (from lumibot)
#   Downloading openai-1.65.4-py3-none-any.whl.metadata (27 kB)
# Collecting msgpack<2.0.0,>=1.0.3 (from alpaca-py>=0.28.1->lumibot)
#   Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Collecting pydantic<3.0.0,>=2.0.3 (from alpaca-py>=0.28.1->lumibot)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting requests<3.0.0,>=2.30.0 (from alpaca-py>=0.28.1->lumibot)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting sseclient-py<2.0.0,>=1.7.2 (from alpaca-py>=0.28.1->lumibot)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting websockets>=10.4 (from alpaca-py>=0.28.1->lumibot)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting tzlocal>=3.0 (from apscheduler>=3.10.4->lumibot)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ccxt>=4.3.74->lumibot) (75.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from ccxt>=4.3.74->lumibot) (2022.12.7)
# Collecting cryptography>=2.6.1 (from ccxt>=4.3.74->lumibot)
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ccxt>=4.3.74->lumibot) (4.12.2)
# Collecting aiohttp<=3.10.11 (from ccxt>=4.3.74->lumibot)
#   Downloading aiohttp-3.10.11-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Collecting aiodns>=1.1.1 (from ccxt>=4.3.74->lumibot)
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting yarl>=1.7.2 (from ccxt>=4.3.74->lumibot)
#   Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl.metadata (71 kB)
# Collecting pyluach (from exchange-calendars>=4.5.2->lumibot)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting toolz (from exchange-calendars>=4.5.2->lumibot)
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: tzdata in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from exchange-calendars>=4.5.2->lumibot) (2025.1)
# Collecting korean_lunar_calendar (from exchange-calendars>=4.5.2->lumibot)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.3->lumibot) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from matplotlib>=3.3.3->lumibot) (2.9.0.post0)
# Collecting narwhals>=1.15.1 (from plotly>=5.18.0->lumibot)
#   Downloading narwhals-1.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.9 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from polygon-api-client>=1.13.3->lumibot) (1.26.15)
# Collecting websockets>=10.4 (from alpaca-py>=0.28.1->lumibot)
#   Downloading websockets-14.2-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting numpy<2,>=1.20.0 (from lumibot)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting seaborn>=0.13.2 (from quantstats-lumi>=0.3.3->lumibot)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: ipython>=8.22.2 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from quantstats-lumi>=0.3.3->lumibot) (8.33.0)
# Collecting multitasking>=0.0.7 (from yfinance>=0.2.54->lumibot)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from yfinance>=0.2.54->lumibot) (4.3.6)
# Collecting frozendict>=2.3.4 (from yfinance>=0.2.54->lumibot)
#   Downloading frozendict-2.4.6-cp310-cp310-win_amd64.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance>=0.2.54->lumibot)
#   Downloading peewee-3.17.9.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 299.6 kB/s eta 0:00:09
#      ------ --------------------------------- 0.5/3.0 MB 299.6 kB/s eta 0:00:09
#      ------ --------------------------------- 0.5/3.0 MB 299.6 kB/s eta 0:00:09
#      ------ --------------------------------- 0.5/3.0 MB 299.6 kB/s eta 0:00:09
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ---------- ----------------------------- 0.8/3.0 MB 305.0 kB/s eta 0:00:08
#      ------------- -------------------------- 1.0/3.0 MB 273.5 kB/s eta 0:00:08
#      ------------- -------------------------- 1.0/3.0 MB 273.5 kB/s eta 0:00:08
#      ------------- -------------------------- 1.0/3.0 MB 273.5 kB/s eta 0:00:08
#      ------------- -------------------------- 1.0/3.0 MB 273.5 kB/s eta 0:00:08
#      ----------------- ---------------------- 1.3/3.0 MB 275.1 kB/s eta 0:00:07
#      ----------------- ---------------------- 1.3/3.0 MB 275.1 kB/s eta 0:00:07
#      ----------------- ---------------------- 1.3/3.0 MB 275.1 kB/s eta 0:00:07
#      -------------------- ------------------- 1.6/3.0 MB 301.7 kB/s eta 0:00:05
#      -------------------- ------------------- 1.6/3.0 MB 301.7 kB/s eta 0:00:05
#      ------------------------ --------------- 1.8/3.0 MB 321.6 kB/s eta 0:00:04
#      ------------------------ --------------- 1.8/3.0 MB 321.6 kB/s eta 0:00:04
#      ------------------------ --------------- 1.8/3.0 MB 321.6 kB/s eta 0:00:04
#      --------------------------- ------------ 2.1/3.0 MB 334.6 kB/s eta 0:00:03
#      --------------------------- ------------ 2.1/3.0 MB 334.6 kB/s eta 0:00:03
#      ------------------------------- -------- 2.4/3.0 MB 355.1 kB/s eta 0:00:02
#      ------------------------------- -------- 2.4/3.0 MB 355.1 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 377.5 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 377.5 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 377.5 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 377.5 kB/s eta 0:00:02
#      ---------------------------------- ----- 2.6/3.0 MB 377.5 kB/s eta 0:00:02
#      -------------------------------------- - 2.9/3.0 MB 360.0 kB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 363.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from yfinance>=0.2.54->lumibot) (4.13.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from openai->lumibot) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai->lumibot)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from openai->lumibot) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai->lumibot)
#   Downloading jiter-0.8.2-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from openai->lumibot) (1.3.1)
# Requirement already satisfied: colorama in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from tqdm->lumibot) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from pytest->lumibot) (1.2.2)
# Collecting iniconfig (from pytest->lumibot)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest->lumibot)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: tomli>=1 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from pytest->lumibot) (2.2.1)
# Collecting inflection>=0.3.1 (from quandl->lumibot)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six in c:\users\rocha\appdata\roaming\python\python310\site-packages (from quandl->lumibot) (1.16.0)
# Collecting more-itertools (from quandl->lumibot)
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy->lumibot)
#   Downloading greenlet-3.1.1-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Collecting ijson (from thetadata->lumibot)
#   Downloading ijson-3.3.0-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Collecting wget (from thetadata->lumibot)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt>=4.3.74->lumibot)
#   Downloading pycares-4.5.0-cp310-cp310-win_amd64.whl.metadata (4.3 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot)
#   Downloading aiohappyeyeballs-2.5.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot) (25.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot)
#   Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot)
#   Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<=3.10.11->ccxt>=4.3.74->lumibot)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->openai->lumibot) (3.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.54->lumibot) (2.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from cryptography>=2.6.1->ccxt>=4.3.74->lumibot) (1.17.1)
# Requirement already satisfied: httpcore==1.* in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from httpx<1,>=0.23.0->openai->lumibot) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->lumibot) (0.14.0)
# Requirement already satisfied: decorator in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (5.14.3)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.3->alpaca-py>=0.28.1->lumibot)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.0.3->alpaca-py>=0.28.1->lumibot)
#   Downloading pydantic_core-2.27.2-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rocha\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.30.0->alpaca-py>=0.28.1->lumibot) (3.1.0)
# Collecting propcache>=0.2.0 (from yarl>=1.7.2->ccxt>=4.3.74->lumibot)
#   Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: pycparser in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=4.3.74->lumibot) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from jedi>=0.16->ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from stack_data->ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from stack_data->ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\rocha\anaconda3\envs\py310_env\lib\site-packages (from stack_data->ipython>=8.22.2->quantstats-lumi>=0.3.3->lumibot) (0.2.3)
# Downloading lumibot-3.9.17-py3-none-any.whl (394 kB)
# Downloading alpaca_py-0.39.0-py3-none-any.whl (121 kB)
# Downloading APScheduler-3.11.0-py3-none-any.whl (64 kB)
# Downloading ccxt-4.4.65-py2.py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.6 MB 762.0 kB/s eta 0:00:07
#    --- ------------------------------------ 0.5/5.6 MB 762.0 kB/s eta 0:00:07
#    --- ------------------------------------ 0.5/5.6 MB 762.0 kB/s eta 0:00:07
#    --- ------------------------------------ 0.5/5.6 MB 762.0 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.8/5.6 MB 441.3 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.8/5.6 MB 441.3 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.8/5.6 MB 441.3 kB/s eta 0:00:11
#    ------- -------------------------------- 1.0/5.6 MB 422.8 kB/s eta 0:00:11
#    ------- -------------------------------- 1.0/5.6 MB 422.8 kB/s eta 0:00:11
#    ------- -------------------------------- 1.0/5.6 MB 422.8 kB/s eta 0:00:11
#    --------- ------------------------------ 1.3/5.6 MB 438.6 kB/s eta 0:00:10
#    --------- ------------------------------ 1.3/5.6 MB 438.6 kB/s eta 0:00:10
#    --------- ------------------------------ 1.3/5.6 MB 438.6 kB/s eta 0:00:10
#    --------- ------------------------------ 1.3/5.6 MB 438.6 kB/s eta 0:00:10
#    ----------- ---------------------------- 1.6/5.6 MB 413.2 kB/s eta 0:00:10
#    ----------- ---------------------------- 1.6/5.6 MB 413.2 kB/s eta 0:00:10
#    ----------- ---------------------------- 1.6/5.6 MB 413.2 kB/s eta 0:00:10
#    ------------- -------------------------- 1.8/5.6 MB 402.7 kB/s eta 0:00:10
#    -------------- ------------------------- 2.1/5.6 MB 436.6 kB/s eta 0:00:09
#    ---------------- ----------------------- 2.4/5.6 MB 472.5 kB/s eta 0:00:07
#    ------------------ --------------------- 2.6/5.6 MB 506.7 kB/s eta 0:00:06
#    ------------------ --------------------- 2.6/5.6 MB 506.7 kB/s eta 0:00:06
#    -------------------- ------------------- 2.9/5
kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ------------------------------------ --- 23.3/25.3 MB 796.3 kB/s eta 0:00:03
#    ---------------------------------------  24.9/25.3 MB 752.7 kB/s eta 0:00:01
#    ---------------------------------------  24.9/25.3 MB 752.7 kB/s eta 0:00:01
#    ---------------------------------------  25.2/25.3 MB 753.3 kB/s eta 0:00:01
#    ---------------------------------------- 25.3/25.3 MB 752.3 kB/s eta 0:00:00
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Downloading SQLAlchemy-2.0.38-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.2 MB/s eta 0:00:00
# Downloading thetadata-0.9.11-py3-none-any.whl (24 kB)
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading aiohttp-3.10.11-cp310-cp310-win_amd64.whl (382 kB)
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 1.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.8/3.2 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.2 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.2 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.2 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.8/3.2 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 2.9/3.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 1.2 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozendict-2.4.6-cp310-cp310-win_amd64.whl (37 kB)
# Downloading greenlet-3.1.1-cp310-cp310-win_amd64.whl (298 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading jiter-0.8.2-cp310-cp310-win_amd64.whl (204 kB)
# Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl (74 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading narwhals-1.29.1-py3-none-any.whl (308 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading pydantic_core-2.27.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.2 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading websockets-14.2-cp310-cp310-win_amd64.whl (164 kB)
# Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl (90 kB)
# Downloading ijson-3.3.0-cp310-cp310-win_amd64.whl (50 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading aiohappyeyeballs-2.5.0-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl (51 kB)
# Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl (28 kB)
# Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl (44 kB)
# Downloading pycares-4.5.0-cp310-cp310-win_amd64.whl (76 kB)
# Building wheels for collected packages: ibapi, peewee, wget
#   Building wheel for ibapi (setup.py): started
#   Building wheel for ibapi (setup.py): finished with status 'done'
#   Created wheel for ibapi: filename=ibapi-9.81.1.post1-py3-none-any.whl size=68023 sha256=686c45b5f2642648699e4cd7bee37d80e5ef1e20252634b460c24551f1109ec9
#   Stored in directory: c:\users\rocha\appdata\local\pip\cache\wheels\e4\77\34\78c9688c4423261f0f80b86e94655e63b2df440a268d56e39f
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139096 sha256=f8a1136f89f05e1bf54a20e1e6370784db8a2563df6211722486e131a6a168a0
#   Stored in directory: c:\users\rocha\appdata\local\pip\cache\wheels\fd\fd\5e\90b9ec95da4fd6c96237b580ce74f89d6bdea547ad151ab5f4
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9710 sha256=dbdb408b176ff138afd94aeb7bc06f29e4a147f4b34b77dfea4becb058ce9bd2
#   Stored in directory: c:\users\rocha\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built ibapi peewee wget
# Installing collected packages: wget, sseclient-py, peewee, multitasking, korean_lunar_calendar, ijson, appdirs, websockets, tzlocal, toolz, tabulate, requests, python-dotenv, pyluach, pydantic-core, pyarrow, psycopg2-binary, propcache, pluggy, numpy, narwhals, multidict, msgpack, more-itertools, jsonpickle, jiter, iniconfig, inflection, ibapi, greenlet, frozenlist, frozendict, duckdb, distro, bcrypt, async-timeout, annotated-types, aiohappyeyeballs, yarl, sqlalchemy, scipy, pytest, pydantic, pycares, polygon-api-client, plotly, holidays, cryptography, apscheduler, aiosignal, yfinance, thetadata, quandl, openai, lumiwealth-tradier, exchange-calendars, alpaca-py, aiohttp, aiodns, seaborn, pandas-market-calendars, ccxt, alpha-vantage, quantstats-lumi, lumibot
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
# Successfully installed aiodns-3.2.0 aiohappyeyeballs-2.5.0 aiohttp-3.10.11 aiosignal-1.3.2 alpaca-py-0.39.0 alpha-vantage-3.0.0 annotated-types-0.7.0 appdirs-1.4.4 apscheduler-3.11.0 async-timeout-5.0.1 bcrypt-4.3.0 ccxt-4.4.65 cryptography-44.0.2 distro-1.9.0 duckdb-1.2.1 exchange-calendars-4.9 frozendict-2.4.6 frozenlist-1.5.0 greenlet-3.1.1 holidays-0.68 ibapi-9.81.1.post1 ijson-3.3.0 inflection-0.5.1 iniconfig-2.0.0 jiter-0.8.2 jsonpickle-4.0.2 korean_lunar_calendar-0.3.1 lumibot-3.9.17 lumiwealth-tradier-0.1.16 more-itertools-10.6.0 msgpack-1.1.0 multidict-6.1.0 multitasking-0.0.11 narwhals-1.29.1 numpy-1.26.4 openai-1.65.4 pandas-market-calendars-4.6.1 peewee-3.17.9 plotly-6.0.0 pluggy-1.5.0 polygon-api-client-1.14.4 propcache-0.3.0 psycopg2-binary-2.9.10 pyarrow-19.0.1 pycares-4.5.0 pydantic-2.10.6 pydantic-core-2.27.2 pyluach-2.2.0 pytest-8.3.5 python-dotenv-1.0.1 quandl-3.7.0 quantstats-lumi-0.3.3 requests-2.32.3 scipy-1.15.2 seaborn-0.13.2 sqlalchemy-2.0.38 sseclient-py-1.8.0 tabulate-0.9.0 thetadata-0.9.11 toolz-1.0.0 tzlocal-5.3.1 websockets-14.2 wget-3.2 yarl-1.18.3 yfinance-0.2.54
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.4 which is incompatible.

# %%
from lumibot.brokers import Alpaca
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies.strategy import Strategy
from lumibot.traders import Trader
from datetime import datetime
from alpaca_trade_api import REST
from timedelta import Timedelta
from finbert_utils import estimate_sentiment

API_KEY = "#"
API_SECRET = "#"
BASE_URL = "#"

ALPACA_CREDS = {
    "API_KEY":API_KEY,
    "API_SECRET":API_SECRET,
    "PAPER":True
}

class MLTrader(Strategy): 
    def initialize(self, symbol:str="SPY", cash_at_risk:float=.5): 
        self.symbol = symbol
        self.sleeptime = "24H" 
        self.last_trade = None 
        self.cash_at_risk = cash_at_risk
        self.api = REST(base_url=BASE_URL, key_id=API_KEY, secret_key=API_SECRET)

    def position_sizing(self): 
        cash = self.get_cash() 
        last_price = self.get_last_price(self.symbol)
        quantity = cash * self.cash_at_risk // last_price
        return cash, last_price, quantity

    def get_dates(self): 
        today = self.get_datetime()
        three_days_prior = today - Timedelta(days=7)
        return today.strftime('%Y-%m-%d'), three_days_prior.strftime('%Y-%m-%d')

    def get_sentiment(self): 
        today, three_days_prior = self.get_dates()
        news = self.api.get_news(symbol=self.symbol, 
                                 start=three_days_prior, 
                                 end=today) 
        news = [ev.__dict__["_raw"]["headline"] for ev in news]
        probability, sentiment = estimate_sentiment(news)
        return probability, sentiment 

    def on_trading_iteration(self):
        cash, last_price, quantity = self.position_sizing() 
        probability, sentiment = self.get_sentiment()
        position = self.get_position(self.symbol)
        if cash > last_price: 
            if sentiment == "positive" and probability > .999: 
                if self.last_trade == "sell": 
                    self.sell_all() 
                order = self.create_order(
                    self.symbol, 
                    quantity, 
                    "buy", 
                    type="bracket", 
                    take_profit_price=last_price*1.20, 
                    stop_loss_price=last_price*.95
                )
                self.submit_order(order) 
                self.last_trade = "buy"
            elif sentiment == "negative" and probability > .999: 
                if self.last_trade == "buy": 
                    self.sell_all() 
                order = self.create_order(
                    self.symbol, 
                    quantity, 
                    "sell", 
                    type="bracket", 
                    take_profit_price=last_price*.8, 
                    stop_loss_price=last_price*1.05
                )
                self.submit_order(order) 
                self.last_trade = "sell"

start_date = datetime(2025,1,1)
end_date = datetime(2025,3,1) 
broker = Alpaca(ALPACA_CREDS) 
strategy = MLTrader(name='mlstrat', broker=broker, 
                    parameters={"symbol":"SPY", 
                                "cash_at_risk":.5})
strategy.backtest(
    YahooDataBacktesting, 
    start_date, 
    end_date, 
    parameters={"symbol":"SPY", "cash_at_risk":.5}
)




'''
start_date = datetime(2025,1,15)
end_date = datetime(2025,2,28)

class MLTrader(Strategy):
    def initialize(self, symbol:str="SPY", cash_at_risk:float=.5):
        self.symbol = symbol
        self.sleeptime = "24H"
        self.last_trade = None
        self.cash_at_risk = cash_at_risk
        self.api = REST(base_url = BASE_URL, key_id = API_KEY, secret_key = API_SECRET)
        
    def position_sizing(self):
        cash = self.get_cash()
        last_price = self.get_last_price(self.symbol)
        quantity = round(cash * self.cash_at_risk / last_price, 0)
        return cash, last_price, quantity

    def get_dates(self):
        today = self.get_datetime()
        three_days_prior = today - Timedelta(days=3)
        return today.strftime('%Y-%m-%d'), three_days_prior.strftime('%Y-%m-%d')
        
    def get_news(self):
        today, three_days_prior = self.get_dates()
        news = self.api.get_news(symbol = self.symbol, start = three_days_prior, end = today)
        news = [ev.__dict__["_raw"]["headline"] for ev in news]
        return news
        
    def on_trading_iteration(self):
        cash, last_price, quantity = self.position_sizing()
    
        # Check if we have an open position
        position = self.get_position(self.symbol)

        if position is None and cash > last_price:  # No position, enough cash → Buy
            news = self.get_news()
            print(news)
            order = self.create_order(
                self.symbol,
                10,
                "buy",
                type="bracket",
                take_profit_price=last_price * 1.20,
                stop_loss_price=last_price * 0.95,
            )
            self.submit_order(order)
            self.last_trade = "buy"
    
        elif position and self.last_trade == "buy":  # Position exists → Sell if conditions met
            # Example: Exit after reaching a profit target or stop loss
            if last_price >= position.entry_price * 1.20 or last_price <= position.entry_price * 0.95:
                order = self.create_order(self.symbol, position.quantity, "sell", type="market")
                self.submit_order(order)
                self.last_trade = None  # Reset for the next trade

broker = Alpaca(ALPACA_CREDS)
strategy = MLTrader(name='mlstrat',broker=broker, 
                    parameters={"symbol":"SPY",
                               "cash_at_risk":.5}
                   )
strategy.backtest(
    YahooDataBacktesting,
    start_date,
    end_date,
    parameters={"symbol":"SPY","cash_at_risk":.5}
)
'''
#lumibot - Easy algo trading framework
#alpaca-trade-api-python - Get news and place trades to broker
#datetime - For date formatting
#timedelta - Calculating time differences
#torch - pytorch framework for using AI/ML
#transformers - Load up finance deep learning model
# Out:
# Progress |██████████████████████████████████████████████████████████████████| 100.00%  [Elapsed: 0:00:20 ETA: 0:00:00]
# '\nstart_date = datetime(2025,1,15)\nend_date = datetime(2025,2,28)\n\nclass MLTrader(Strategy):\n    def initialize(self, symbol:str="SPY", cash_at_risk:float=.5):\n        self.symbol = symbol\n        self.sleeptime = "24H"\n        self.last_trade = None\n        self.cash_at_risk = cash_at_risk\n        self.api = REST(base_url = BASE_URL, key_id = API_KEY, secret_key = API_SECRET)\n        \n    def position_sizing(self):\n        cash = self.get_cash()\n        last_price = self.get_last_price(self.symbol)\n        quantity = round(cash * self.cash_at_risk / last_price, 0)\n        return cash, last_price, quantity\n\n    def get_dates(self):\n        today = self.get_datetime()\n        three_days_prior = today - Timedelta(days=3)\n        return today.strftime(\'%Y-%m-%d\'), three_days_prior.strftime(\'%Y-%m-%d\')\n        \n    def get_news(self):\n        today, three_days_prior = self.get_dates()\n        news = self.api.get_news(symbol = self.symbol, start = three_days_prior, end = today)\n        news = [ev.__dict__["_raw"]["headline"] for ev in news]\n        return news\n        \n    def on_trading_iteration(self):\n        cash, last_price, quantity = self.position_sizing()\n    \n        # Check if we have an open position\n        position = self.get_position(self.symbol)\n\n        if position is None and cash > last_price:  # No position, enough cash → Buy\n            news = self.get_news()\n            print(news)\n            order = self.create_order(\n                self.symbol,\n                10,\n                "buy",\n                type="bracket",\n                take_profit_price=last_price * 1.20,\n                stop_loss_price=last_price * 0.95,\n            )\n            self.submit_order(order)\n            self.last_trade = "buy"\n    \n        elif position and self.last_trade == "buy":  # Position exists → Sell if conditions met\n            # Example: Exit after reaching a profit target or stop loss\n            if last_price >= position.entry_price * 1.20 or last_price <= position.entry_price * 0.95:\n                order = self.create_order(self.symbol, position.quantity, "sell", type="market")\n                self.submit_order(order)\n                self.last_trade = None  # Reset for the next trade\n\nbroker = Alpaca(ALPACA_CREDS)\nstrategy = MLTrader(name=\'mlstrat\',broker=broker, \n                    parameters={"symbol":"SPY",\n                               "cash_at_risk":.5}\n                   )\nstrategy.backtest(\n    YahooDataBacktesting,\n    start_date,\n    end_date,\n    parameters={"symbol":"SPY","cash_at_risk":.5}\n)\n'

# %%
from lumibot.brokers import Alpaca
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies.strategy import Strategy
from datetime import datetime, timedelta
from alpaca_trade_api import REST
from timedelta import Timedelta
from finbert_utils import estimate_sentiment
import numpy as np

API_KEY = "#"
API_SECRET = "#"
BASE_URL = "#"

ALPACA_CREDS = {
    "API_KEY": API_KEY,
    "API_SECRET": API_SECRET,
    "PAPER": True
}

class MLTrader(Strategy):
    def initialize(self, symbol="SPY", cash_at_risk=0.5):
        self.symbol = symbol
        self.sleeptime = "24H"
        self.last_trade = None
        self.cash_at_risk = cash_at_risk
        self.api = REST(base_url=BASE_URL, key_id=API_KEY, secret_key=API_SECRET)

    def get_volatility(self, symbol, period=20):
        # Try fetching historical prices with the lookback period
        bars = self.get_historical_prices(symbol, length=20, timestep="day")  # Adjust length as needed


        # Debugging: Print bars info
        print("Bars:", bars)
        print("Type of bars:", type(bars))

        # Ensure bars is valid
        if bars is None or not hasattr(bars, "__iter__") or not list(bars):
            print("Error: bars is empty or not iterable")
            return None  

        # Convert to DataFrame if possible
        if hasattr(bars, "to_dataframe"):
            bars = bars.to_dataframe()
            if bars.empty:
                print("Bars converted to empty DataFrame")
                return None

        # Assuming bars is a DataFrame, calculate volatility
        returns = bars["close"].pct_change().dropna()
        volatility = returns.std()

        return volatility









    def position_sizing(self):
        cash = self.get_cash()
        last_price = self.get_last_price(self.symbol)
        volatility = self.get_volatility(self.symbol, period=20)

        # Adjust position size based on volatility
        adjusted_cash_at_risk = min(0.5, max(0.1, 1 / (volatility + 1e-6)))
        quantity = cash * adjusted_cash_at_risk // last_price
        return cash, last_price, quantity

    def get_dates(self):
        today = self.get_datetime()
        seven_days_prior = today - Timedelta(days=7)
        return today.strftime('%Y-%m-%d'), seven_days_prior.strftime('%Y-%m-%d')

    def get_sentiment(self):
        today, seven_days_prior = self.get_dates()
        news = self.api.get_news(symbol=self.symbol, start=seven_days_prior, end=today)
        
        headlines = [ev.__dict__["_raw"]["headline"] for ev in news] if news else []
        
        if not headlines:  
            return 0, "neutral"

        probabilities, sentiments = estimate_sentiment(headlines)
        avg_sentiment = np.mean(probabilities)

        return avg_sentiment, "positive" if avg_sentiment > 0.7 else "negative" if avg_sentiment < 0.3 else "neutral"

    def on_trading_iteration(self):
        cash, last_price, quantity = self.position_sizing()
        probability, sentiment = self.get_sentiment()

        # Get moving averages for trend confirmation
        sma_50 = self.get_sma(self.symbol, 50)
        sma_200 = self.get_sma(self.symbol, 200)
        uptrend = last_price > sma_50 > sma_200
        downtrend = last_price < sma_50 < sma_200

        position = self.get_position(self.symbol)
        entry_price = position.entry_price if position else None

        # Buy Logic
        if cash > last_price and sentiment == "positive" and probability > 0.7 and uptrend:
            if self.last_trade == "sell":
                self.sell_all()

            order = self.create_order(
                self.symbol, quantity, "buy", type="trailing_stop", trail_percent=5
            )
            self.submit_order(order)
            self.last_trade = "buy"

        # Sell Logic
        elif sentiment == "negative" and probability > 0.7 and downtrend:
            if self.last_trade == "buy":
                self.sell_all()

            order = self.create_order(
                self.symbol, quantity, "sell", type="trailing_stop", trail_percent=5
            )
            self.submit_order(order)
            self.last_trade = "sell"

        # Stop loss check
        if position and entry_price:
            if last_price >= entry_price * 1.20 or last_price <= entry_price * 0.95:
                self.sell_all()

# Backtesting
start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 3, 1)

broker = Alpaca(ALPACA_CREDS)
strategy = MLTrader(name="mlstrat", broker=broker, parameters={"symbol": "SPY", "cash_at_risk": 0.5})

strategy.backtest(
    YahooDataBacktesting,
    start_date,
    end_date,
    parameters={"symbol": "SPY", "cash_at_risk": 0.5}
)
# Out:
# Bars:                                  open        high         low       close  \|   2.37%  [Elapsed: 0:00:01 ETA: 0:01:14]
# Date
# 2024-12-03 16:00:00-05:00  603.390015  604.159973  602.340027  603.909973
# 2024-12-04 16:00:00-05:00  605.630005  607.909973  604.950012  607.659973
# 2024-12-05 16:00:00-05:00  607.659973  608.479980  606.299988  606.659973
# 2024-12-06 16:00:00-05:00  607.440002  609.070007  607.020020  607.809998
# 2024-12-09 16:00:00-05:00  607.690002  607.859985  604.080017  604.679993
# 2024-12-10 16:00:00-05:00  605.369995  605.799988  602.130005  602.799988
# 2024-12-12 16:00:00-05:00     -0.005153        0.000000 -0.005153
# 2024-12-13 16:00:00-05:00     -0.000199        0.000000 -0.000199
# 2024-12-16 16:00:00-05:00      0.004270        0.000000  0.004270
# 2024-12-17 16:00:00-05:00     -0.004120        0.000000 -0.004120
# 2024-12-18 16:00:00-05:00     -0.029803        0.000000 -0.029803
# 2024-12-19 16:00:00-05:00     -0.000307        0.000000 -0.000307
# 2024-12-20 16:00:00-05:00      0.008616        0.003326  0.011942
# 2024-12-23 16:00:00-05:00      0.005988        0.000000  0.005988
# 2024-12-24 16:00:00-05:00      0.011115        0.000000  0.011115
# 2024-12-26 16:00:00-05:00      0.000067        0.000000  0.000067
# 2024-12-27 16:00:00-05:00     -0.010527        0.000000 -0.010527
# 2024-12-30 16:00:00-05:00     -0.011412        0.000000 -0.011412
# 2024-12-31 16:00:00-05:00     -0.003638        0.000000 -0.003638
# Type of bars: <class 'lumibot.entities.bars.Bars'>
# Error: bars is empty or not iterable
# 2025-03-08 22:22:25,124: ERROR: unsupported operand type(s) for +: 'NoneType' and 'float'
# 2025-03-08 22:22:25,126: ERROR: [MLTrader] Traceback (most recent call last):
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 1059, in run
#     self._run_trading_session()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 999, in _run_trading_session
#     self._on_trading_iteration()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 306, in func_output
#     result = func_input(self, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 331, in func_output
#     result = func_input(self, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 466, in _on_trading_iteration
#     raise e
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 434, in _on_trading_iteration
#     on_trading_iteration()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\tools\decorators.py", line 62, in func_output
#     frame, result = call_function_get_frame(func_input, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\tools\decorators.py", line 30, in call_function_get_frame
#     result = func(*args, **kwargs)
#   File "C:\Users\rocha\AppData\Local\Temp\ipykernel_20972\1983715958.py", line 93, in on_trading_iteration
#     cash, last_price, quantity = self.position_sizing()
#   File "C:\Users\rocha\AppData\Local\Temp\ipykernel_20972\1983715958.py", line 69, in position_sizing
#     adjusted_cash_at_risk = min(0.5, max(0.1, 1 / (volatility + 1e-6)))
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'
# Exception in thread MLTrader:
# Traceback (most recent call last):
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 1059, in run
#     self._run_trading_session()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 999, in _run_trading_session
#     self._on_trading_iteration()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 306, in func_output
#     result = func_input(self, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 331, in func_output
#     result = func_input(self, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 466, in _on_trading_iteration
#     raise e
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 434, in _on_trading_iteration
#     on_trading_iteration()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\tools\decorators.py", line 62, in func_output
#     frame, result = call_function_get_frame(func_input, *args, **kwargs)
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\tools\decorators.py", line 30, in call_function_get_frame
#     result = func(*args, **kwargs)
#   File "C:\Users\rocha\AppData\Local\Temp\ipykernel_20972\1983715958.py", line 93, in on_trading_iteration
#   File "C:\Users\rocha\AppData\Local\Temp\ipykernel_20972\1983715958.py", line 69, in position_sizing
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Users\rocha\anaconda3\envs\py310_env\lib\site-packages\lumibot\strategies\strategy_executor.py", line 1072, in run
#     raise RuntimeError("Exception encountered, stopping BackTest.") from e
# RuntimeError: Exception encountered, stopping BackTest.
# 2025-03-08 22:22:27,523: ERROR: Not enough data to create a tearsheet, at least 2 days of data are required. Skipping
# {}
